# %%
# !ls
# Out:
# 11_predict.ipynb               hunger.csv
# 202011_data.csv                predicting.py
# 202011_predict.csv             toyota_a.csv
# 202011_predict.py              toyota_kfold3.py
# 202011month.csv                toyota_model_report_final.pptx
# Untitled.ipynb                 toyota_n.py
# deeplearning (2).zip           toyota_new.csv
# elu_SGD_final                  toyota_prediction_final.csv
# elu_adam_final

# %%
data = pd.read_csv('./toyota_prediction_final.csv', encoding='cp949')

# %%
data.drop(['Unnamed: 0'],1,inplace=True)

# %%
data
# Out:
#           년 Month Advertiser Product ad_id   sp  grp       Aud  Reach1+  \
# 0      2021   04월       삼성전자   삼성갤럭시  남60대  2.0  1.9   44413.0      1.9
# 1      2021   04월       삼성전자   삼성갤럭시  남30대  2.0  0.0       0.0      0.0
# 2      2021   04월       삼성전자   삼성갤럭시  남20대  2.0  1.6   27620.0      1.6
# 3      2021   04월       삼성전자   삼성갤럭시  남40대  2.0  3.1   65309.0      3.1
# 4      2021   04월       삼성전자   삼성갤럭시  남50대  2.0  4.6   93650.0      4.4
# ...     ...   ...        ...     ...   ...  ...  ...       ...      ...
# 20105  2021   04월     엘엑스컴퍼니   링스지엔씨  여60대  2.0  7.0  192151.0      3.7
# 20106  2021   04월     엘엑스컴퍼니   링스지엔씨  여50대  2.0  4.7   96305.0      3.2
# 20107  2021   04월     엘엑스컴퍼니   링스지엔씨  여40대  2.0  2.5   50645.0      1.7
# 20108  2021   04월     엘엑스컴퍼니   링스지엔씨  여20대  2.0  0.0       0.0      0.0
# 20109  2021   04월     엘엑스컴퍼니   링스지엔씨  여30대  2.0  0.0       0.0      0.0
#
#        Reach3+  ...  Month_11월  Month_12월    ZSCORE  predict_reg_0  \
# ...

# %%
data = pd.read_csv('./202011_data.csv')

# %%
data.drop(['Unnamed: 0'],1,inplace=True)

# %%
data
# Out:
#     grp   sp     Aud  Reach1+  Reach3+  Reach5+  Reach7+  Reach9+  Reach12+  \
# 0    11  295  189235      9.0      0.5      0.0      0.0      0.0       0.0
# 1     7  295  134605      5.0      0.5      0.0      0.0      0.0       0.0
# 2    25  295  527070     16.7      2.9      0.0      0.0      0.0       0.0
# 3    13  295  265787     10.1      0.6      0.0      0.0      0.0       0.0
# 4    16  295  405692      8.3      1.2      0.4      0.4      0.4       0.1
# 5     6  295  106664      3.4      0.8      0.0      0.0      0.0       0.0
# 6     7  295  153982      5.5      0.4      0.0      0.0      0.0       0.0
# 7    13  295  292772      9.8      1.2      0.0      0.0      0.0       0.0
# 8    16  295  326015     11.3      1.7      0.0      0.0      0.0       0.0
# 9    11  295  249478      7.6      0.8      0.0      0.0      0.0       0.0
# 10   13  613  218092      5.9      1.6      0.9      0.0      0.0       0.0
# ...

# %%
data
